# %% [markdown]
# # Spotify Suggestion Model V3

# %% [markdown]
# ## Infrastructure

# %%
import sys
# !{sys.executable} -m pip install spotipy

# %%
username = "agwx2"
cid = "17c11cf9271f4980a85e6aab83cba6bb" 
secret = "015c9abf126340a7981e7ba64dbe7828"
# good_playlist_id = "61BmnG6d7ifmj8Dr5tuCBK"
# bad_playlist_ids = "53FPslFSIAGvVyERcNG4J3"
# source_playlist_id = "5ghFHvZmV4FDK5YLeZQRu9"
good_playlist_ids = [
    "37i9dQZF1DX48TTZL62Yht",   # Hip Hop Favourites
    "37i9dQZF1EQnqst5TRi17F",   # Hip Hop Mix
    "37i9dQZF1DX7FY5ma9162x",   # R&B Favourites
    "37i9dQZF1EQoqCH7BwIYb7",   # R&B Mix
    "53FPslFSIAGvVyERcNG4J3",   # Trap/R&B (personal mix)
    # "37i9dQZF1DWWEcRhUVtL8n"    # Indie Pop
]
bad_playlist_ids = [
    "37i9dQZF1EQpj7X7UK8OOF",   # Rock Mix
    "37i9dQZF1DX1kCIzMYtzum",   # EDM
    "37i9dQZF1DXbITWG1ZJKYt",   # Jazz Classics
    "37i9dQZF1EQmPV0vrce2QZ",   # Country Mix
    "37i9dQZF1EQncLwOalG3K7",   # Pop Mix
    "61BmnG6d7ifmj8Dr5tuCBK"    # Classic Rock (personal mix)
]
source_playlist_ids = [
    # "37i9dQZF1DXb57FjYWz00c",   # 80s Hits
    # "37i9dQZF1EQn2GRFTFMl2A",   # 90s Mix
    # "37i9dQZF1DWUZv12GM5cFk",   # 2000s Hits
    # "37i9dQZF1DXc6IFF23C9jj",   # 2010s Hits
    "5ghFHvZmV4FDK5YLeZQRu9",   # Top 100 (personal mix)
]
source_playlist_id = source_playlist_ids[0]

# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split


from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.linear_model import LinearRegression, LogisticRegression

from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## Data Collection

# %%
sp_cred = SpotifyClientCredentials(
    client_id=cid,
    client_secret=secret
)
sp = spotipy.Spotify(client_credentials_manager=sp_cred)

# %%
all_good_ids = []
for good_playlist_id in good_playlist_ids:
  good_playlist = sp.user_playlist(username, good_playlist_id)
  good_tracks = good_playlist["tracks"]
  good_songs = good_tracks["items"]

  while good_tracks['next']:
      good_tracks = sp.next(good_tracks)
      for item in good_tracks["items"]:
          good_songs.append(item)

  good_ids = []
  for i in range(len(good_songs)):
      good_ids.append(good_songs[i]['track']['id'])
  print(len(good_ids))
  all_good_ids += good_ids
print("")
print(len(all_good_ids))
print(all_good_ids)
# Out:
# 100
# 50
# 100
# 50
# 217
#
# 517
# ['2SAqBLGA283SUiwJ3xOUVI', '0mG6igzxbH55XRyq3ygEh8', '5IUtvfNvOyVYZUa6AJFrnP', '57VeLYXrvNxe8Vs18K2M9W', '18vXApRmJSgQ6wG2ll9AOg', '5sBplhIrmzA4kQGyIOpmDf', '0k7wmahjkn389wAZdz19Cv', '2MbdDtCv5LUVjYy9RuGTgC', '4TIqzdAssasqx3DAe6cG9J', '6ZoZ4KGIDD23DohdVk0Ybw', '6rTInqW3YECMkQsBEHw4sd', '33gwZOGJWEZ7dRWPqPxBEZ', '7o4gBbTM6UBLkOYPw9xMCz', '2hx8cZug1bgRMXgW5RCTUV', '1VLtjHwRWOVJiE5Py7JxoQ', '35RJhm1pEovTBwnNR0zWad', '1tkg4EHVoqnhR6iFEXb60y', '1JXBNvlDEl2epKSJ9EOgKX', '3w1WjD2zJqjBjDz5fwqQPJ', '3mDFLytDotXo2p0rvfGbkA', '0PJ4dXVkpNAtoOZsEjqktc', '26UxwWl9xCb83OynXELJcL', '1H7KnK26kc1YyellpbINEn', '2NM0qHzx4Ohy8iXHEEgwlO', '1inQjfrPjWSM8DehYMfIxi', '7v96VvFLS0wSYT8kewNLRy', '341lTIxmhybbQsgydwJiFx', '3zs87EV3EZSh2UpiXxT52Y', '527k23H0A4Q0UJN3vGs0Da', '21AJQhGZpujjZQXByZAXpr', '37Nqx7iavZpotJSDXZWbJ3', '0cu0rhnlCnJ7JIeHRiLpj3', '6wJYhPfqk3KGhHRG76WzOh', '2t7D3y0jvYjR8IP9Bosyew', '3McTpsUQfEDrlNd2ikro2E', '6EDO9iiTtwNv6waLwa1UUq', '3AMxuq6id3YGB57eWeheZQ', '2M2Pug4zwMialHSwACPlU1', '6wQlQrTY5mVS8EGaFZVwVF', '1Tfxi7N3DW4zvAuVjt9g8X', '2T5NBwKRySiCR78vVk08vr', '1t9WgS8FN0534tLBRwbaxO', '5nLNuK7OoJt36gY9gWgnbo', '0E72UaOjGEOHJliDjq6Ivw', '5T0ahhwM0f4YYExfIGEHVw', '07twUUK8jWUCVsrSoEgbLW', '17vGPZ5EsdvtgAOCD4FLWI', '5SWnsxjhdcEDc7LJjq9UHk', '2cnKST6T9qUo2i907lm8zX', '7zVVkNOKWMd46nwMUgHPmL', '7E2C5rBLpCKwQlhJPVFBRS', '5ChX0Yt1wPpRJFPPecJZPh', '0JjM9bKm4wrwohMslcm892', '3SLu421u9hMKwcFNxGFrGk', '3tjFYV6RSFtuktYl3ZtYcq', '7ytR5pFWmSjzHJIeQkgog4', '2tDrlnQWiCDis4H8RT0W2h', '65UMCdooEyQ6dQHmbgwEVS', '37AGgp9VP8TVJBfEat74Bj', '6CN7FuZ7o1xle9TNxApGeQ', '3QzAOrNlsabgbMwlZt7TAY', '6UFEJuDXQMWhL5UH5f9fUR', '5q9Et9kJTWvRg80uQLBW4s', '1EWkw4Fa6IlnsAihLUlFFM', '6x9q8zyUs4vOiZmKqbFkCl', '04VO6VICgMJgTe2dLxFBoW', '5gub2bpJRgJP4m4MliqtdV', '0Zc86nmtzsx3Tlzv7sC8Pc', '5YSHygGN9D0mID1NsVd5my', '6gi6y1xwmVszDWkUqab1qw', '4nyRXQQkM69kmaxiyCKMCr', '7sO5G9EABYOXQKNPNiE9NR', '7CmNyEQUpNSX6RMM5Fw3os', '2kQkKSsZlfdLBPHS3xkymN', '4cSSL3YafYjM3yjgFO1vJg', '0BGwAKW4u8kWOhWFflZxfl', '0qJeyYAgv6UpvewUxRXAhb', '2zR8U7MLwxlLf7xkAew9BR', '7HspJ4PdLV4Qw6SNiQKjTf', '7nQ5vYfpRleN1UPTD1vgj1', '3eekarcy7kvN4yt5ZFzltW', '7Ko12sPqhdCczAdJ6wnyAc', '1wJRveJZLSb1rjhnUHQiv6', '15bnyEOUVRkwWlxR4F7xzF', '4xqIYGwwZTEem9U8A42SPF', '3CEqLxEEEzaO07Ts3xoTFR', '63cd4JkwGgYJrbOizbfmsp', '3UDvm8ln2Xo11NZY34lT9G', '2tUL6dZf1mywCj5WvCPZw6', '4iHSE5R1U8jf84tRn52xRt', '0C1T6YOwB7MMzspV0UbKKA', '5LHHKZOwV8XW4LJP2C64mw', '5CFJRZRq6sdKKtRwNPWbYv', '1XXimziG1uhM0eDNCZCrUl', '0XqrIEnDoHvodUzGRmyKYQ', '5wMh9hhqKQ4JfqLuvqAC7s', '2ap9kKsIEiWa4bzsjqACEx', '5OtK4qowbxqNC2dueZR3ju', '3jT2LKH0RSbQ8jIUNFzXm5', '5jbDih9bLGmI8ycUKkN5XA', '0BMYkkkkgrkI6Xhogm8gUR', '4hsTQQgfBnBgtBkTGKWS1G', '15JINEqzVMv3SvJTAXAKED', '1pqHv4SgUoIZf8UCW3zwte', '0Fs9cdPDhptWEDJmiCbkEW', '5Bv6jNkvB82p6NCeaFsVuA', '5bx4stZRInFwFz40fHDa7h', '3urzNdNEHoL46L7RgPxmyO', '2muh7P8rylTiI0IJIn2d3z', '7lQWRAjyhTpCWFC0jmclT4', '4x79VTxsny238G39AweIq0', '5MwNk30sG4xRpsDdUgUwC2', '5bZnSJZEqbBsXxHI5Qszxy', '3yfqSUWxFvZELEM4PmlwIR', '6LNoArVBBVZzUTUiAX2aKO', '6mDcLPGVCmdhMN4gBzNb7s', '1VLtjHwRWOVJiE5Py7JxoQ', '5szZ6W382mKvLz1nmWV1CF', '4VXIryQMWpIdGgYR4TrjT1', '2Gd0oV24QsH0zb9nKFx7s5', '6gBFPUFcJLzWGx4lenP6h2', '1uMHCAyGmHqyygoNRuo7MV', '40iJIUlhi6renaREYGeIDS', '79s5XnCN4TJKTVMSmOx8Ep', '1v7L65Lzy0j0vdpRjJewt1', '7x5A8tRuDcw9qoRQ7W0OA3', '6Hfu9sc7jvv6coyy2LlzBF', '3oF1ZBHm7qDn3bOxIrDEjy', '0SobxwXrtsbqRv9jnrMeWa', '3aIATlpQ3pnYPc7ebsBuRk', '4jPy3l0RUwlUI9T5XHBW2m', '285pBltuF7vW8TeWk8hdRR', '3gxAIJwFeYpba15gx9zXre', '0SGdM4FZggUwklexYWCzR1', '4XvcHTUfIlWfyJTRG0aqlo', '6iuEK9IFiwlbchU6Fg35x4', '7lQ8MOhq6IN2w8EYcFNSUk', '68GdZAAowWDac3SkdNWOwo', '0k1WUmIRnG3xU6fvvDVfRG', '2vTin2H3idCl2nuc3CqdPR', '0I3q5fE6wg7LIfHGngUTnV', '5U2oQrjYu3VqQoH5OAyyxq', '5EhNalC8HJFOMNbCFibHqB', '1T43ASu3jRDUOtv80ebNJO', '67ttkEO235xJmxhQ9tOM1t', '1kXOujFqMAZklF7jXhzcg1', '2xWjwGfjevKxgB36wkMzZb', '5cQsVuIWmtNLPkx531n9YM', '3zx5ne2XxVwFcPg4t6OxRC', '7rklm17yoayxw45lpzv5uv', '4HDCLYli2SUdkq9OjmvhSD', '18O00Y7yrkJ0pRXm1n21Og', '1Jz1yhcPm1Yt6aoed3zact', '5OdNjYTpLjuDDPCBNWon ...

# %%
all_bad_ids = []
for bad_playlist_id in bad_playlist_ids:
  bad_playlist = sp.user_playlist(username, bad_playlist_id)
  bad_tracks = bad_playlist["tracks"]
  bad_songs = bad_tracks["items"]

  while bad_tracks['next']:
      bad_tracks = sp.next(bad_tracks)
      for item in bad_tracks["items"]:
          bad_songs.append(item)

  bad_ids = []
  for i in range(len(bad_songs)):
      bad_ids.append(bad_songs[i]['track']['id'])
  print(len(bad_ids))
  all_bad_ids += bad_ids
print("")
print(len(all_bad_ids))
print(all_bad_ids)
# Out:
# 50
# 75
# 200
# 50
# 50
# 132
#
# 557
# ['0MKGH8UMfCnq5w7nG06oM5', '71SvEDmsOwIWw1IozsZoMA', '6KTv0Z8BmVqM7DPxbGzpVC', '2fuCquhmrzHpu5xcA1ci9x', '59WN2psjkt1tyaxjspN8fp', '7pKfPomDEeI4TPT6EOYjn9', '4pt5fDVTg5GhEvEtlz9dKk', '7N3PAbqfTjSEU1edb2tY8j', '003vvx7Niy0yvhvHt4a68B', '4BP3uh0hFLFRb5cjsgLqDh', '5zA8vzDGqPl2AzZkEYQGKh', '1f3yAtsJtY87CTmM8RLnxf', '1lCRw5FEZ1gPDNPzy1K4zW', '2zYzyRzz6pRmhPzyfMEC8s', '254bXAqt3zP6P50BdQvEsq', '5tVA6TkbaAH9QMITTQRrNv', '70LcF31zb1H0PyJoS1Sx1r', '1QFh8OH1e78dGd3VyJZCAC', '2Cdvbe2G4hZsnhNMKyGrie', '40riOy7x9W7GXjyGp4pjAv', '5T8EDUDqKcs6OSOwEsfqG7', '6Qyc6fS4DsZjB2mRW9DsQs', '6dGnYIeXmHdcikdzNNDMm2', '3gdewACMIVMEWVbyb8O9sY', '20OFwXhEXf12DzwXmaV7fj', '08mG3Y1vljYA6bvDt4Wqkj', '4o6BgsqLIBViaGVbx5rbRk', '4cIPLtg1avt2Jm3ne9S1zy', '11LmqTE2naFULdEP94AUBa', '2gT72HL4Y84K2Mle3miAMJ', '0ofHAoxe9vBkTCp2UQIavz', '5XcZRgJv3zMhTqCyESjQrF', '2RlgNHKcydI9sayD2Df2xp', '13CR9dPNbuH2li1xaepFe0', '40i81AcCCxiVEFUWElcjZC', '4bHsxqR3GMrXTxEPLuK5ue', '57bgtoPSgt236HzfBOd8kj', '37Tmv4NnfQeb0ZgUC4fOJj', '0WSa1sucoNRcEeULlZVQXj', '2nLtzopw4rPReszdYBJU6h', '1JSTJqkT5qHq8MDJnJbRE1', '3d9DChrdc6BOeFsbrZ3Is0', '3yrSvpt2l1xhsV9Em88Pul', '3Vby4nGmtbDo7HDJamOWkT', '5qqabIl2vWzo9ApSC317sa', '3fH4KjXFYMmljxrcGrbPj9', '7wuJGgpTNzbUyn26IOY6rj', '7wCmS9TTVUcIhRalDYFgPy', '37ZJ0p5Jm13JPevGcx4SkF', '2374M0fQpWi3dLnB54qaLX', '7nlXw2qQ38tx4UvBwVL5Ne', '7GiozRoMk95aFl1WbrDdjX', '0ha2skoePlU0BDDySj8qf2', '1OU3OPHczBcfFU8cDzSzKT', '0gNXY64y1CKoNsIo96WuLn', '7clsGP3ea7rhBaEK9ga898', '1O3Jlr6ksM6meUe1atDAxY', '0PMNxtgeNSmPPp4aiA4T8F', '7IhWJM8cN04zRQ2PNM91xc', '4548LyFomXQmDAINcFizEq', '2prnn41CblB8B4yWACDljP', '7pDdE5FLqcNCvjxzRzm80r', '5MxKAr6Ui5hQ9TtjdnlmrR', '2dyrLrVopYKGc3H9oOYSmZ', '0aEIw4siCqZ8hlDrvtlRep', '7arsXR8AtExnOFN3v3HiJI', '59o6ojGNGJOYiVJSzC6Lsa', '2cGnOx17iac6m7R5YDUZac', '2gZwBmkSmsVfEPFWGuWTDk', '2Q8fFORnsDE6I3RNvSLXSf', '6D9pncRlZZoq4oc1tzAC1y', '1bmvJkAA8Yz9bv6y3WOj3U', '4IiuExPFijOGZnVxGsKWcc', '6ft4hAq6yde8jPZY2i5zLr', '1p04Tm0c2tnIdgOYIpcioh', '3AygCrAj6TZZ6mGkcvD9To', '0GevQZGBPYjfPzK8e3jxzl', '27bZ77uG7mEhydpaPvThR6', '3UTnoLehZjISbFueAmhGvY', '0NMhB5jf4SJhzqnx6pBHNh', '7u6EvUNJUmycM4IHEiHasm', '3CbqAQnT7oU23IvtcHO0k1', '1FxZblJPTjTl7SWSOwdmBk', '0d2F9wcykuZ1QzDMcI0Mf0', '0g8YU2bR0QlBv7G9L9nDXU', '1OfHes9WQdGQSIgNwrqIAw', '7Jhhj33A2qNRpLuo51Aqwt', '273n4aGEPcL1HrcdhpGGul', '7tVVAfQ4zG2r0WVL5pQjVX', '4ga4WvRNhMsIL38pkBbnIN', '7nvaEKdCDWbnQK7uJsCS5y', '45srzqej6QL7I5CQtorj0d', '3zQpGaH50HeMjxurMZVF6q', '7jXQUrVhEpXdymfFWNDnQW', '5Apm1AC2iO9thO32d5bA8y', '7sFk2PA3NsrrSsGa4CM3rs', '0cvMWzztDy1wNQkBqae8w4', '6UMbXtJQL8dRQfiLdFh63O', '48fPdAwGVoSkGK8GSez9yx', '5K6Ssv4Z3zRvxt0P6EKUAP', '6IzwNz9jjHpvEqWmyLYUXa', '7BPTtDK064b41v0LiopTnC', '1suqXPrYygZ7BYiSfaVZE4', '5FDdviWQzhw7NWH2TiDl9d', '2cXlDeF2sUoZRQgYQZ2nb0', '22y2mqIBERBviZF0fa86iw', '04zCkONaIDxTx2gDjV1yCd', '1HPJpgceRg6KPO11nMhWlt', '3S2ArNKZEcb9JiBX9WAv4z', '0PGpWcKIlayTwPdz6Qstol', '4iqmktYiX3g7jAwr73i6yC', '6F3htwbMYqes3xVs5Vorkm', '6f3Slt0GbA2bPZlz0aIFXN', '5emTyRnoMTLc9G44RR6XIE', '46BhtWkz8zKHdABv0yzxV7', '0hvOu1yvUgbjNrzXfWVLYS', '0vR2rIVORmgeKiGIgNT0fV', '6S2MDC31VIH79OwGU87L0s', '4gEC7He07d6cuzkQ7MSobQ', '71H8k9qe7DersxR6KyhUnI', '5W05N4aETUauCVzddI8L66', '7IiLh65OUiHNWTFXpsAzY1', '0RHtecK6xMtW7yWgmLmOpQ', '5erj647SYiDcIR8Zwi6tc9', '4QDlt4NhI93bs9TI5s1sCc', '1pZn8AX1WulW8IO338hE5D', '3iFlfQ0CXc9URaAvai8VUe', '5F8rPLt2c52p0SK7kiH26b', '7unF2ARDGldwWxZWCmlwDM', '4Y5fyQ5fBysC32Na5sZT3J', '7KsJkshpIjjeIwyKnkhQUc', '2IdwQxhJn9ZE4zIotcCefR', '0cNc2tivyPqzgp13BSM7St', '0ldmR2mJJNEoBIINfZWdv6', '30QD4VRP9yEneOh0eGTrtJ', '1BPmVDqR4cX9aFC0Qx0eWn', '4R6rf3KbP45JST6Cr3Enry', '6yKkA8HzwWTZ5taIMaG4Nm', '1cpANF6zMBoFoxkoIjZHjv', '6f7r5i4xVwePkHDHwwMK75', '5TNpCThzzXHEipXGKgNG8T', '0m8tSPLHhjhGToD6LW0RPp', '5z7deaTe21B7QVPhSDouL1', '3pfbQmD5xGH9Tcc7GqGfSL', '34zhjduFdQFhkRUJ230h9T', '5eFFsShr8vchESCk8HGxvn', '0GUUhTWMylAx5pHDI42t1V', '016HKF7A4O7tatoJ9BgZM1', '6eimz6jvlZaPwtflDWCTa0', '7Kwi4xmgY4qQwOhBe0zsbh', '2EW1mFJaikQh0vxOoB7uGp', '7yYgBAj3yaMdTgq7fIvDlQ', '09g9OlH3RDjbffMAnvBPgw', '0Rk9byjmZksAJX15onGn ...

# %%
source_playlist = sp.user_playlist(username, source_playlist_id)
source_tracks = source_playlist["tracks"]
source_songs = source_tracks["items"]

while source_tracks['next']:
    source_tracks = sp.next(source_tracks)
    for item in source_tracks["items"]:
        source_songs.append(item)

source_ids = []
for i in range(len(source_songs)):
    if source_songs[i]['track'] != None:
      source_ids.append(source_songs[i]['track']['id'])
print(len(source_ids))
print(source_ids)
# Out:
# 122
# ['0Dm43YLUlGdePpSbI1ct8h', '70eFcWOvlMObDhURTqT4Fv', '1DhRbox3xkceP64k3JeYfW', '3FHXUqaUer9o231Je1zxIN', '2md2i5QvelRFnafpnd6LOg', '1z3L82jeYnTmYUjPc7zXcu', '1MJ5f5EYBC92ADD6xcz7nb', '0W0R48uImgPVVJgb5YTC3I', '0nMqu5vN44GNv8UOQxmBJK', '5pgZpHqfv4TSomtkfGZGrG', '14rWEXQGBsFB7ALUc8G4sr', '4sqIBV3ukQDqRr8Me2nvQb', '1QvpsbjYAVVFvFrWVC0qnQ', '6Wz9rIfo9tOBcVCd1Mo7F7', '3OUyyDN7EZrL7i0Sbi5SVd', '32q9OuCp7wFdLZKuCXm0wl', '5JWPUEov2wlX7c0jhYZpeB', '2BITQ360Knh6qNAOqR7Dyq', '5O2Yjlcs5pSpHq1gcA0cwg', '23bOfmnZiN42pB1frXNyak', '1LwwZ0xoUz5gR8XrxEUKAK', '17aVK3oQdgwVG2l0HpP67W', '25nzKGDiua1lE9Qo5V19GL', '60dwJ8dnqZ4WrIdiu7LkNR', '7KrlNS2VqiNNJ82RMQdxBn', '2xdwCJLfKCkat14mlgR26M', '3Jbpo2slhW2bbVneiJnC9G', '4dVbhS6OiYvFikshyaQaCN', '5UWwZ5lm5PKu6eKsHAGxOk', '67vYdAAM3oGsEImCRfbtsF', '3ptB4SmuSJTGhQByFrMJVJ', '2CDVqsGGkf2v1tMETt3fq5', '4QMSoa7Fh3y4kmMNuBtOgt', '1F9kEuwT29fgqlovIclu81', '0EC0kuRKIUlru5eRxWYYyv', '6KYVWcOQWm7JrlsPMkrkNi', '732Sqj2piYPhdMPENP4axz', '0ooz46SAYMJsdOPnwW4nKK', '1mSClObliRtgPVT399COQH', '2K22nUTdyr48JDwI5t906t', '7C0rG4oWO7VeZcffyW1sK9', '1fpvdpEUe6jncotfqNGRW8', '5fXzip3wTVAfVIzpl5Hkvm', '5PntSbMHC1ud6Vvl8x56qd', '77WttH8P9XpfIMozhTvRql', '58AGoOGbwsQMhBbH0eFLRR', '4Bjwyj8KM85xblkSt5A24j', '0FtuxFKzjbVCQAA3UQZXll', '0WkvlY12giGlrnWw0UkcuX', '7pv80uUHfocFqfTytu1MVi', '7GHqPV9RCRofSXh68htAkg', '3PP9CXeE0PYaM5GIGQqBIV', '5wCVLW9qMtIY9IkBeyYnh6', '55KGNC101dEVfdAGAzUIeq', '25MZ70BQLAARDutsAXcdYu', '2gQaQUhDCNGfBVXTvxAmXQ', '5uDohC8URXwbGiHAMuKGoa', '4BIWl6xOUupdv3jpWtPSDC', '0WTHb1o71zwLCLwX4R0IGz', '0aF9m87P8Tja3NUMv4DfHt', '3fH4KjXFYMmljxrcGrbPj9', '4qjscZh4jfhkpcQG4ZQfi2', '3JOVTQ5h8HGFnDdp4VT3MP', '0rT9f5BSZrZ6DvzfBEckG0', '6yBGRo2sQ87Y9YukSKLnvu', '0tPShxf8VJUH6RBDEP3tVB', '2Tix9H6H3SSVutryoi0Cer', '6N7gPTru90HYLRUIVDQ185', '4gnPzSCKecLy9WJeHeJBrk', '2pVym24miJgEbF170Is2lO', '0KZWXucjRxwQaXkpbv4iqI', '2FHdkquBesDIZZ0IcVYaFc', '4LSxhWoG9I6SQFMkd6X031', '545g4jlvOqZo1sj6k1f9j9', '75H83SSOTlLX8915pP4W8F', '0ZNvlBnanNNKx3Rw1paoeL', '5fHgBb5r91Jmdr8Q7dwmad', '6wL2rgm1Gf60jgZli5YJqs', '2DI0fZ4QZmLtapszYaoG6F', '4wajJ1o7jWIg62YqpkHC7S', '1hvpkfNJ1EfkF9SS2yBuml', '1WWXpMOiO8lsnOCjQrLYd7', '3TZ5SUq3BSWYSJCg5Xke8k', '6ilOjlJMBMSAWolY3xHZ1i', '4GKk1uNzpxIptBuaY97Dkj', '1pm5dCU51YP8GaEGiLf8ug', '45D0ixQWzXQOoU1S9aSnKk', '5B6Z7NwVqA7W3UFiqBdEJC', '4RvWPyQ5RL0ao9LPZeSouE', '0LN5gIsS5tQSmRzQrHSaTR', '0F4XDqPUvM1Onfvdm6qcSV', '2WfaOiMkCvy7F5fcp2zZ8L', '0VFfZVCFNe1I2IIChVBR5m', '0ikz6tENMONtK6qGkOrU3c', '0Qv7xi6uPSqH2k82tOkGSt', '2PFIZFcGry0po3ZfRZkzKc', '23IJ5wLRhEZ9DOuia5mPiZ', '2Z17Q91PB11tzkDh0QQtd6', '3PAKizczXMROvbg9GrdURh', '00NAQYOP4AmWR549nnYJZu', '0Xam0zVac3hKWWN4OQ5Gdr', '57JVGBtBLCfHw2muk5416J', '3ybF6Iaia01EbXg5VmxPcb', '6KsgCYcZKPcBRDNGhiZWRR', '6VS4OTcpylKl984tzFYC11', '18URo35acNKRTHfEdjTcGn', '5SZ6zX4rOrEQferfFC2MfP', '4qgZs0RNjdzKAS22lP0QjY', '5svBTKTKa8S8jaZqV3XZgv', '0GjEhVFGZW8afUYGChu3Rr', '2fYwXajnfsfp4APMSop4Uc', '6RKGBcDtgzXx21zUjpeu6F', '5Ea66YQ4u2nePfHsM5UezQ', '5d4ERnrRRe9o4I7aFLFTvP', '1OXBfwBYtj2AAKi6jom1qT', '54eZmuggBFJbV7k248bTTt', '5lfNSjn4xu0JT8SL78AkKa', '3OrqExOwr13y6UCI1LGhA4', '5dV2mUBoEAQFXhgiptE9pq', '7kULe6tZxvByCsfng9D5rD', '0IedgQjjJ8Ad4B3UDQ5Lyn', '6lvJDlBrtabJWiBlMTGxKs']

# %%
training_features = []

for i in range(0, len(all_good_ids), 50):
  audio_features = sp.audio_features(all_good_ids[i : i + 50])
  for track in audio_features:
    if track != None:

      track['target'] = 1
      training_features.append(track)
      # training_features[-1]['target'] = 1

for i in range(0, len(all_bad_ids), 50):
  audio_features = sp.audio_features(all_bad_ids[i : i + 50])
  for track in audio_features:
    if track != None:
      track['target'] = 0
      training_features.append(track)
      # training_features[-1]['target'] = 0

print(len(training_features))
print(training_features)
# Out:
# 1073
# [{'danceability': 0.761, 'energy': 0.518, 'key': 0, 'loudness': -8.871, 'mode': 1, 'speechiness': 0.134, 'acousticness': 0.244, 'instrumentalness': 3.47e-05, 'liveness': 0.107, 'valence': 0.522, 'tempo': 133.976, 'type': 'audio_features', 'id': '2SAqBLGA283SUiwJ3xOUVI', 'uri': 'spotify:track:2SAqBLGA283SUiwJ3xOUVI', 'track_href': 'https://api.spotify.com/v1/tracks/2SAqBLGA283SUiwJ3xOUVI', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2SAqBLGA283SUiwJ3xOUVI', 'duration_ms': 261493, 'time_signature': 4, 'target': 1}, {'danceability': 0.775, 'energy': 0.518, 'key': 6, 'loudness': -5.857, 'mode': 0, 'speechiness': 0.311, 'acousticness': 0.455, 'instrumentalness': 0, 'liveness': 0.121, 'valence': 0.646, 'tempo': 161.011, 'type': 'audio_features', 'id': '0mG6igzxbH55XRyq3ygEh8', 'uri': 'spotify:track:0mG6igzxbH55XRyq3ygEh8', 'track_href': 'https://api.spotify.com/v1/tracks/0mG6igzxbH55XRyq3ygEh8', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mG6igzxbH55XRyq3ygEh8', 'duration_ms': 123987, 'time_signature': 4, 'target': 1}, {'danceability': 0.782, 'energy': 0.51, 'key': 4, 'loudness': -5.724, 'mode': 0, 'speechiness': 0.0419, 'acousticness': 0.143, 'instrumentalness': 0, 'liveness': 0.115, 'valence': 0.118, 'tempo': 99.993, 'type': 'audio_features', 'id': '5IUtvfNvOyVYZUa6AJFrnP', 'uri': 'spotify:track:5IUtvfNvOyVYZUa6AJFrnP', 'track_href': 'https://api.spotify.com/v1/tracks/5IUtvfNvOyVYZUa6AJFrnP', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IUtvfNvOyVYZUa6AJFrnP', 'duration_ms': 143375, 'time_signature': 4, 'target': 1}, {'danceability': 0.945, 'energy': 0.582, 'key': 11, 'loudness': -8.357, 'mode': 0, 'speechiness': 0.0719, 'acousticness': 0.114, 'instrumentalness': 0, 'liveness': 0.103, 'valence': 0.907, 'tempo': 108.025, 'type': 'audio_features', 'id': '57VeLYXrvNxe8Vs18K2M9W', 'uri': 'spotify:track:57VeLYXrvNxe8Vs18K2M9W', 'track_href': 'https://api.spotify.com/v1/tracks/57VeLYXrvNxe8Vs18K2M9W', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57VeLYXrvNxe8Vs18K2M9W', 'duration_ms': 168906, 'time_signature': 4, 'target': 1}, {'danceability': 0.789, 'energy': 0.536, 'key': 6, 'loudness': -6.862, 'mode': 1, 'speechiness': 0.242, 'acousticness': 0.41, 'instrumentalness': 0, 'liveness': 0.129, 'valence': 0.437, 'tempo': 81.039, 'type': 'audio_features', 'id': '18vXApRmJSgQ6wG2ll9AOg', 'uri': 'spotify:track:18vXApRmJSgQ6wG2ll9AOg', 'track_href': 'https://api.spotify.com/v1/tracks/18vXApRmJSgQ6wG2ll9AOg', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18vXApRmJSgQ6wG2ll9AOg', 'duration_ms': 165926, 'time_signature': 4, 'target': 1}, {'danceability': 0.832, 'energy': 0.549, 'key': 1, 'loudness': -8.259, 'mode': 0, 'speechiness': 0.0602, 'acousticness': 0.168, 'instrumentalness': 0, 'liveness': 0.11, 'valence': 0.384, 'tempo': 140.045, 'type': 'audio_features', 'id': '5sBplhIrmzA4kQGyIOpmDf', 'uri': 'spotify:track:5sBplhIrmzA4kQGyIOpmDf', 'track_href': 'https://api.spotify.com/v1/tracks/5sBplhIrmzA4kQGyIOpmDf', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5sBplhIrmzA4kQGyIOpmDf', 'duration_ms': 181496, 'time_signature': 4, 'target': 1}, {'danceability': 0.752, 'energy': 0.658, 'key': 0, 'loudness': -6.297, 'mode': 1, 'speechiness': 0.342, 'acousticness': 0.0421, 'instrumentalness': 0, 'liveness': 0.0927, 'valence': 0.387, 'tempo': 151.951, 'type': 'audio_features', 'id': '0k7wmahjkn389wAZdz19Cv', 'uri': 'spotify:track:0k7wmahjkn389wAZdz19Cv', 'track_href': 'https://api.spotify.com/v1/tracks/0k7wmahjkn389wAZdz19Cv', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0k7wmahjkn389wAZdz19Cv', 'duration_ms': 213520, 'time_signature': 4, 'target': 1}, {'danceability': 0.904, 'energy': 0.723, 'key': 11, 'loudness': -5.224, 'mode': 0, 'speechiness': 0.26, 'acousticness': 0.0631, 'instrumentalness': 0, 'liveness': 0.185, 'valence': 0.835, 'tempo': 145.013, 'type': 'audio_features', 'id': '2MbdDtCv5LUVjYy9RuGTgC', 'uri': 'spotify:track:2MbdDtCv5LUVjYy9RuGTgC' ...

# %%
source_features = []
for i in range(0, len(source_ids), 50):
    audio_features = sp.audio_features(source_ids[i : i + 50])
    for track in audio_features:
        track['target'] = 0
        source_features.append(track)
        # source_features[-1]['target'] = 0  # arbitrary

print(len(source_features))
print(source_features)
# Out:
# 122
# [{'danceability': 0.662, 'energy': 0.624, 'key': 10, 'loudness': -13.606, 'mode': 0, 'speechiness': 0.0417, 'acousticness': 0.165, 'instrumentalness': 0, 'liveness': 0.0674, 'valence': 0.961, 'tempo': 174.513, 'type': 'audio_features', 'id': '0Dm43YLUlGdePpSbI1ct8h', 'uri': 'spotify:track:0Dm43YLUlGdePpSbI1ct8h', 'track_href': 'https://api.spotify.com/v1/tracks/0Dm43YLUlGdePpSbI1ct8h', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Dm43YLUlGdePpSbI1ct8h', 'duration_ms': 252560, 'time_signature': 4, 'target': 0}, {'danceability': 0.64, 'energy': 0.647, 'key': 5, 'loudness': -8.114, 'mode': 0, 'speechiness': 0.186, 'acousticness': 0.124, 'instrumentalness': 0, 'liveness': 0.0801, 'valence': 0.546, 'tempo': 92.979, 'type': 'audio_features', 'id': '70eFcWOvlMObDhURTqT4Fv', 'uri': 'spotify:track:70eFcWOvlMObDhURTqT4Fv', 'track_href': 'https://api.spotify.com/v1/tracks/70eFcWOvlMObDhURTqT4Fv', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/70eFcWOvlMObDhURTqT4Fv', 'duration_ms': 197867, 'time_signature': 4, 'target': 0}, {'danceability': 0.716, 'energy': 0.823, 'key': 5, 'loudness': -5.313, 'mode': 0, 'speechiness': 0.0495, 'acousticness': 0.132, 'instrumentalness': 0, 'liveness': 0.361, 'valence': 0.91, 'tempo': 151.957, 'type': 'audio_features', 'id': '1DhRbox3xkceP64k3JeYfW', 'uri': 'spotify:track:1DhRbox3xkceP64k3JeYfW', 'track_href': 'https://api.spotify.com/v1/tracks/1DhRbox3xkceP64k3JeYfW', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DhRbox3xkceP64k3JeYfW', 'duration_ms': 161747, 'time_signature': 4, 'target': 0}, {'danceability': 0.468, 'energy': 0.63, 'key': 8, 'loudness': -6.536, 'mode': 0, 'speechiness': 0.0843, 'acousticness': 0.31, 'instrumentalness': 0, 'liveness': 0.137, 'valence': 0.762, 'tempo': 91.419, 'type': 'audio_features', 'id': '3FHXUqaUer9o231Je1zxIN', 'uri': 'spotify:track:3FHXUqaUer9o231Je1zxIN', 'track_href': 'https://api.spotify.com/v1/tracks/3FHXUqaUer9o231Je1zxIN', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3FHXUqaUer9o231Je1zxIN', 'duration_ms': 204507, 'time_signature': 4, 'target': 0}, {'danceability': 0.397, 'energy': 0.903, 'key': 2, 'loudness': -4.577, 'mode': 1, 'speechiness': 0.0457, 'acousticness': 0.00575, 'instrumentalness': 1.6e-06, 'liveness': 0.362, 'valence': 0.556, 'tempo': 151.551, 'type': 'audio_features', 'id': '2md2i5QvelRFnafpnd6LOg', 'uri': 'spotify:track:2md2i5QvelRFnafpnd6LOg', 'track_href': 'https://api.spotify.com/v1/tracks/2md2i5QvelRFnafpnd6LOg', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2md2i5QvelRFnafpnd6LOg', 'duration_ms': 201373, 'time_signature': 4, 'target': 0}, {'danceability': 0.511, 'energy': 0.404, 'key': 2, 'loudness': -6.77, 'mode': 1, 'speechiness': 0.0273, 'acousticness': 0.603, 'instrumentalness': 0, 'liveness': 0.0879, 'valence': 0.535, 'tempo': 145.8, 'type': 'audio_features', 'id': '1z3L82jeYnTmYUjPc7zXcu', 'uri': 'spotify:track:1z3L82jeYnTmYUjPc7zXcu', 'track_href': 'https://api.spotify.com/v1/tracks/1z3L82jeYnTmYUjPc7zXcu', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1z3L82jeYnTmYUjPc7zXcu', 'duration_ms': 199813, 'time_signature': 4, 'target': 0}, {'danceability': 0.537, 'energy': 0.558, 'key': 11, 'loudness': -8.678, 'mode': 1, 'speechiness': 0.0929, 'acousticness': 0.263, 'instrumentalness': 0.91, 'liveness': 0.102, 'valence': 0.505, 'tempo': 131.037, 'type': 'audio_features', 'id': '1MJ5f5EYBC92ADD6xcz7nb', 'uri': 'spotify:track:1MJ5f5EYBC92ADD6xcz7nb', 'track_href': 'https://api.spotify.com/v1/tracks/1MJ5f5EYBC92ADD6xcz7nb', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1MJ5f5EYBC92ADD6xcz7nb', 'duration_ms': 231724, 'time_signature': 4, 'target': 0}, {'danceability': 0.548, 'energy': 0.693, 'key': 5, 'loudness': -10.499, 'mode': 0, 'speechiness': 0.041, 'acousticness': 0.0858, 'instrumentalness': 0.944, 'liveness': 0.0758, 'valence': 0.857, 'tempo': 81.469, 'type': 'audio_features', 'id': '0W0R48uImgPVVJgb5YTC3I', 'uri': 'spotify:track:0W0R48uImgPV ...

# %% [markdown]
# ## Data Preparation

# %%
trainingData = pd.DataFrame(training_features)

# %%
trainingData
# Out:
#       danceability  energy  key  ...  duration_ms  time_signature  target
# 0            0.761   0.518    0  ...       261493               4       1
# 1            0.643   0.403    1  ...       174682               4       1
# 2            0.829   0.512    6  ...       123987               4       1
# 3            0.904   0.723   11  ...       227478               4       1
# 4            0.782   0.510    4  ...       143375               4       1
# ...            ...     ...  ...  ...          ...             ...     ...
# 1068         0.547   0.987    8  ...       178627               4       0
# 1069         0.469   0.537    9  ...       382834               1       0
# 1070         0.322   0.265    2  ...       226667               4       0
# 1071         0.373   0.453    9  ...       196841               4       0
# 1072         0.659   0.838    1  ...       240400               4       0
#
# [1073 rows x 19 columns]

# %%
train, test = train_test_split(trainingData, test_size = 0.15)

# %%
target_features = ["danceability", "loudness", "valence", "energy", "instrumentalness", "acousticness", "key", "speechiness", "duration_ms"]

x_train = train[target_features]
y_train = train["target"]
x_test = test[target_features]
y_test = test["target"]

# %%
x_train
# Out:
#      danceability  loudness  valence  ...  key  speechiness  duration_ms
# 742         0.470   -12.824    0.243  ...   10       0.0365       284560
# 282         0.630    -6.152    0.487  ...    6       0.0334       249867
# 82          0.829    -4.937    0.312  ...    2       0.1020       135431
# 401         0.769    -4.064    0.490  ...    7       0.2620       164038
# 528         0.502    -4.556    0.720  ...    1       0.0564       301920
# ..            ...       ...      ...  ...  ...          ...          ...
# 117         0.766   -12.561    0.816  ...   10       0.0790       184800
# 517         0.500    -5.846    0.539  ...    4       0.0388       218920
# 42          0.719    -7.600    0.660  ...    3       0.1250       123263
# 870         0.616    -5.968    0.386  ...    1       0.0298       213387
# 380         0.604    -5.979    0.287  ...    1       0.0545       197573
#
# [912 rows x 9 columns]

# %%
y_train
# Out:
# 742    0
# 282    1
# 82     1
# 401    1
# 528    0
#       ..
# 117    1
# 517    0
# 42     1
# 870    0
# 380    1
# Name: target, Length: 912, dtype: int64

# %%
x_test
# Out:
#      danceability  loudness  valence  ...  key  speechiness  duration_ms
# 400         0.570    -7.562   0.2700  ...    6       0.2220       180016
# 263         0.793    -8.134   0.8980  ...    5       0.2710       193740
# 752         0.597   -16.656   0.3400  ...    9       0.0491       254400
# 536         0.579    -9.484   0.6090  ...    2       0.0270       391376
# 569         0.521    -3.184   0.0868  ...    1       0.0558       195000
# ..            ...       ...      ...  ...  ...          ...          ...
# 925         0.685    -8.285   0.5780  ...    2       0.0345       190779
# 996         0.336   -10.875   0.4270  ...    9       0.0840       355304
# 329         0.813    -5.541   0.5470  ...    2       0.2860       192132
# 725         0.421   -21.795   0.0546  ...    7       0.0400       257693
# 176         0.762    -8.937   0.3940  ...    5       0.1870       203145
#
# [161 rows x 9 columns]

# %%
y_test
# Out:
# 400    1
# 263    1
# 752    0
# 536    0
# 569    0
#       ..
# 925    0
# 996    0
# 329    1
# 725    0
# 176    1
# Name: target, Length: 161, dtype: int64

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Random Forest

# %%
# random forest combines multiple decision trees and uses bagging
# (training multiple trees on different sections of training data, averaging the result)
rfc = RandomForestClassifier(n_jobs=1, random_state=1)
rfc.fit(x_train, y_train)
rfc_pred = rfc.predict(x_test)

score = accuracy_score(y_test, rfc_pred) * 100
print("Accuracy using Random Forest: ", round(score, 2), "%")
print('Mean squared error: %.2f' % mean_squared_error(y_test, rfc_pred))
# Out:
# Accuracy using Random Forest:  88.82 %
# Mean squared error: 0.11

# %% [markdown]
# Measured Accuracy: 88.82%

# %% [markdown]
# ### Gradient Boosting

# %%
# I <3 gradient boost
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=.1, max_depth=1, random_state=1)
gbc.fit(x_train, y_train)
gbc_pred = gbc.predict(x_test)

score = accuracy_score(y_test, gbc_pred) * 100
print("Accuracy using Gradient Boost: ", round(score, 2), "%")
print('Mean squared error: %.2f' % mean_squared_error(y_test, gbc_pred))
# Out:
# Accuracy using Gradient Boost:  90.68 %
# Mean squared error: 0.09

# %% [markdown]
# Measured Accuracy: 90.68%

# %% [markdown]
# ### Gradient Boosting w/ Manual Stacking (Random Forest)

# %%
x_train_rfc = (x_train.iloc[0:int(len(x_train) / 2)]).copy()
y_train_rfc = (y_train.iloc[0:int(len(y_train) / 2)]).copy()
x_train_gbc = (x_train.iloc[int(len(x_train) / 2):len(x_train)]).copy()
y_train_gbc = (y_train.iloc[int(len(y_train) / 2):len(y_train)]).copy()

# %%
x_test_rfc = x_train_gbc
y_test_rfc = y_train_gbc
x_test_gbc = x_test.copy()
y_test_gbc = y_test.copy()

# %%
rfc_stack = RandomForestClassifier(n_jobs=1, random_state=1)
rfc_stack.fit(x_train_rfc, y_train_rfc)
rfc_stack_pred_train = rfc_stack.predict(x_test_rfc)

score = accuracy_score(y_test_rfc, rfc_stack_pred) * 100
print("Accuracy using Random Forest: ", round(score, 2), "%")
print('Mean squared error: %.2f' % mean_squared_error(y_test_rfc, rfc_stack_pred))
# Out:
# Accuracy using Random Forest:  87.72 %
# Mean squared error: 0.12

# %%
rfc_stack_pred_test = rfc_stack.predict(x_test_gbc)

# %%
# stack
x_train_gbc['rfc_stack_pred'] = rfc_stack_pred_train.tolist()
x_test_gbc['rfc_stack_pred'] = rfc_stack_pred_test.tolist()

# %%
x_train_gbc
# Out:
#       danceability  loudness  valence  ...  speechiness  duration_ms  rfc_stack_pred
# 1046         0.263    -6.189    0.504  ...       0.0982       408853               0
# 57           0.751    -6.859    0.634  ...       0.1770       171892               1
# 157          0.771    -6.844    0.182  ...       0.0718       148927               1
# 179          0.697    -9.774    0.805  ...       0.0891       166717               1
# 809          0.653   -11.567    0.249  ...       0.0439       524093               0
# ...            ...       ...      ...  ...          ...          ...             ...
# 117          0.766   -12.561    0.816  ...       0.0790       184800               1
# 517          0.500    -5.846    0.539  ...       0.0388       218920               0
# 42           0.719    -7.600    0.660  ...       0.1250       123263               1
# 870          0.616    -5.968    0.386  ...       0.0298       213387               0
# 380          0.604    -5.979    0.287  ...       0.0545       197573               0
#
# [456 rows x 10 columns]

# %%
x_test_gbc
# Out:
#      danceability  loudness  valence  ...  speechiness  duration_ms  rfc_stack_pred
# 400         0.570    -7.562   0.2700  ...       0.2220       180016               1
# 263         0.793    -8.134   0.8980  ...       0.2710       193740               1
# 752         0.597   -16.656   0.3400  ...       0.0491       254400               0
# 536         0.579    -9.484   0.6090  ...       0.0270       391376               0
# 569         0.521    -3.184   0.0868  ...       0.0558       195000               0
# ..            ...       ...      ...  ...          ...          ...             ...
# 925         0.685    -8.285   0.5780  ...       0.0345       190779               1
# 996         0.336   -10.875   0.4270  ...       0.0840       355304               0
# 329         0.813    -5.541   0.5470  ...       0.2860       192132               1
# 725         0.421   -21.795   0.0546  ...       0.0400       257693               0
# 176         0.762    -8.937   0.3940  ...       0.1870       203145               1
#
# [161 rows x 10 columns]

# %%
gbc_stack = GradientBoostingClassifier(n_estimators=100, learning_rate=.1, max_depth=1, random_state=1)
gbc_stack.fit(x_train_gbc, y_train_gbc)
gbc_stack_pred = gbc_stack.predict(x_test_gbc)

score = accuracy_score(y_test_gbc, gbc_stack_pred) * 100
print("Accuracy using Gradient Boost: ", round(score, 2), "%")
print('Mean squared error: %.2f' % mean_squared_error(y_test_gbc, gbc_stack_pred))
# Out:
# Accuracy using Gradient Boost:  88.2 %
# Mean squared error: 0.12

# %% [markdown]
# Measured Accuracy: 88.2%

# %% [markdown]
# ### Stacking Classifier

# %%
base_learners = [
  ('rf_1', RandomForestClassifier(n_estimators=10, random_state=42)),
  ('rf_2', KNeighborsClassifier(n_neighbors=5)),             
]

stk = StackingClassifier(estimators=base_learners, final_estimator=LogisticRegression())
stk.fit(x_train, y_train)
stk_pred = stk.predict(x_test)

score = accuracy_score(y_test, stk_pred) * 100
print("Accuracy using Gradient Boost: ", round(score, 2), "%")
print('Mean squared error: %.2f' % mean_squared_error(y_test, stk_pred))
# Out:
# Accuracy using Gradient Boost:  88.2 %
# Mean squared error: 0.12

# %% [markdown]
# Measured Accuracy: 88.2%

# %%
base_learners = [
  ('rf_1', RandomForestClassifier(n_estimators=10, random_state=42)),
  ('rf_2', KNeighborsClassifier(n_neighbors=5)),             
  ('rf_3', GradientBoostingClassifier(n_estimators=100, learning_rate=.1, max_depth=1, random_state=1))
]

stk = StackingClassifier(estimators=base_learners, final_estimator=LogisticRegression())
stk.fit(x_train, y_train)
stk_pred = stk.predict(x_test)

score = accuracy_score(y_test, stk_pred) * 100
print("Accuracy using Gradient Boost: ", round(score, 2), "%")
print('Mean squared error: %.2f' % mean_squared_error(y_test, stk_pred))
# Out:
# Accuracy using Gradient Boost:  89.44 %
# Mean squared error: 0.11

# %% [markdown]
# Measured Accuracy: 89.44%

# %% [markdown]
# ### Neural Networks

# %% [markdown]
# #### Baseline

# %%
def keras_nn_baseline_model_small():
  model = Sequential()
  model.add(Dense(9, input_dim=9, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
def keras_nn_baseline_model_big():
  model = Sequential()
  model.add(Dense(9, input_dim=9, activation='relu'))
  model.add(Dense(18, input_dim=9, activation='relu'))
  model.add(Dense(90, input_dim=18, activation='sigmoid'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
def keras_nn_baseline_model_shaped():
  model = Sequential()
  model.add(Dense(5, input_dim=9, activation='relu'))
  model.add(Dense(60, input_dim=5, activation='sigmoid'))
  model.add(Dense(5, input_dim=60, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %% [markdown]
# #### Pipeline w/ Normalization

# %%
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasClassifier(build_fn=keras_nn_baseline_model_shaped, epochs=200, batch_size=5, verbose=0)))
keras_pipeline = Pipeline(estimators)

# %%
kfold = StratifiedKFold(n_splits=10, shuffle=True)
results = cross_val_score(keras_pipeline, x_train, y_train, cv=kfold)
print("Standardized: %.2f%% (%.2f%%)" % (results.mean() * 100, results.std() * 100))
# Out:
# Standardized: 88.27% (2.06%)

# %% [markdown]
# **Cross-Validation Scores**
# keras_nn_baseline_model_small: 87.51%
# keras_nn_baseline_model_big: 85.09%
# keras_nn_baseline_model_shaped: 88.27%

# %%
keras_pipeline.fit(x_train, y_train)
keras_pred = keras_pipeline.predict(x_test)

score = accuracy_score(y_test, keras_pred) * 100
print("Accuracy using NN: ", round(score, 2), "%")
print('Mean squared error: %.2f' % mean_squared_error(y_test, keras_pred))
# Out:
# Accuracy using NN:  90.68 %
# Mean squared error: 0.09

# %% [markdown]
# ### Neural Networks w/ Stacking

# %%
def get_nn_classifier():
  nn_clf = KerasClassifier(build_fn=keras_nn_baseline_model_shaped, epochs=200, batch_size=5, verbose=0)
  nn_clf._estimator_type = "classifier"
  estimators = []
  estimators.append(('standardize', StandardScaler()))
  estimators.append(('mlp', nn_clf))
  return Pipeline(estimators)

# %%
base_learners = [
  ('rf_1', RandomForestClassifier(n_estimators=10, random_state=42)),
  ('rf_2', KNeighborsClassifier(n_neighbors=5)),             
  ('rf_3', GradientBoostingClassifier(n_estimators=100, learning_rate=.1, max_depth=1, random_state=1)),
  ('rf_4', get_nn_classifier())
]

nn_stk = StackingClassifier(estimators=base_learners, final_estimator=LogisticRegression())
nn_stk.fit(x_train, y_train)
nn_stk_pred = nn_stk.predict(x_test)

score = accuracy_score(y_test, nn_stk_pred) * 100
print("Accuracy using NN & Stacking: ", round(score, 2), "%")
print('Mean squared error: %.2f' % mean_squared_error(y_test, nn_stk_pred))
# Out:
# Accuracy using Gradient Boost:  90.06 %
# Mean squared error: 0.10

# %% [markdown]
# Measured Accuracy: 90.06%

# %% [markdown]
# ## Generate Predictions

# %%
sourceData = pd.DataFrame(source_features)
sourceData = sourceData[target_features]

# %%
sourceData
# Out:
#      danceability  loudness  valence  ...  key  speechiness  duration_ms
# 0           0.662   -13.606   0.9610  ...   10       0.0417       252560
# 1           0.640    -8.114   0.5460  ...    5       0.1860       197867
# 2           0.716    -5.313   0.9100  ...    5       0.0495       161747
# 3           0.468    -6.536   0.7620  ...    8       0.0843       204507
# 4           0.397    -4.577   0.5560  ...    2       0.0457       201373
# ..            ...       ...      ...  ...  ...          ...          ...
# 117         0.519    -9.982   0.4880  ...    5       0.0795        82147
# 118         0.615    -8.615   0.7470  ...    0       0.0443       263673
# 119         0.512    -5.128   0.8380  ...    7       0.3540        40227
# 120         0.807    -9.729   0.9610  ...    0       0.0433       279773
# 121         0.500    -9.995   0.0766  ...    0       0.0395       157000
#
# [122 rows x 9 columns]

# %%
# model = gbc
# model = keras_pipeline
model = nn_stk

# %%
pred = model.predict(sourceData)

# %%
source_playlist_songs[0]
# Out:
# {'added_at': '2020-10-01T05:24:42Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agwx2'},
#   'href': 'https://api.spotify.com/v1/users/agwx2',
#   'id': 'agwx2',
#   'type': 'user',
#   'uri': 'spotify:user:agwx2'},
#  'is_local': False,
#  'primary_color': None,
#  'track': None,
#  'video_thumbnail': None}

# %%
source_playlist_songs = source_playlist['tracks']['items']

print("ACCEPTED")


i = 0
for prediction in pred:
    if prediction == 1 and i + 1 < len(source_playlist_songs):
        song_title = source_playlist_songs[i + 1]['track']['name']
        artist_name = source_playlist_songs[i + 1]['track']['artists'][0]['name']
        print ("Song: " + song_title + ", By: "+ artist_name)
    i = i + 1


print("REJECTED")

i = 0
for prediction in pred:
    if prediction == 0 and i + 1 < len(source_playlist_songs):
        song_title = source_playlist_songs[i + 1]['track']['name']
        artist_name = source_playlist_songs[i + 1]['track']['artists'][0]['name']
        print ("Song: " + song_title + ", By: "+ artist_name)
    i = i + 1
# Out:
# ACCEPTED
# Song: Beautiful People (feat. Khalid), By: Ed Sheeran
# Song: Revolution 909, By: Daft Punk
# Song: That's Life, By: Still Woozy
# Song: Order More (feat. Starrah), By: G-Eazy
# Song: Paper Trail$, By: Joey Bada$$
# Song: Baby, By: Brandy
# Song: I Like Dat, By: T-Pain
# Song: Lost Cause, By: Billie Eilish
# Song: STUNNAMAN (with Roddy Ricch & feat. Lil Wayne), By: Birdman
# Song: Baddest (feat. Chris Brown & 2 Chainz), By: Yung Bleu
# Song: Y U DON'T LOVE ME? (MISS AMERIKKKA), By: Joey Bada$$
# Song: Easy Love, By: Lauv
# Song: DRUGS, By: Tai Verdes
# Song: Loser, By: Beck
# Song: Run To The Sun, By: N.E.R.D
# Song: Crush, By: Souly Had
# Song: Didn't Cha Know, By: Erykah Badu
# Song: Red (Brothel Remix), By: Lucy Daydream
# Song: Rocky, By: Still Woozy
# Song: Butterflies, By: Michael Jackson
# Song: Bake Sale (feat. Travis Scott), By: Wiz Khalifa
# Song: CASINO, By: Ashton Travis
# Song: favorable colours, By: slenderbodies
# Song: Outside, By: Weston Estate
# Song: Another One Bites The Dust - Remastered 2011, By: Queen
# REJECTED
# Song: Part-Time Lover, By: Stevie Wonder
# Song: Antisocial (with Travis Scott), By: Ed Sheeran
# Song: I Don't Want Your Money (feat. H.E.R.), By: Ed Sheeran
# Song: Meant to Live, By: Switchfoot
# Song: Meant To Live - Acoustic Version, By: Switchfoot
# Song: Chamber Of Reflection, By: Mac DeMarco
# Song: Wavy, By: Janko Nilovic
# Song: Malibu 1992, By: COIN
# Song: Soap On Your Skin, By: The Solids
# Song: Across The Overpass, By: The Solids
# Song: Hey Beautiful - From "How I Met Your Mother"/Theme, By: The Solids
# Song: Twenty Something, By: Nightly
# Song: BYE, By: Jaden
# Song: Lost In Yesterday, By: Tame Impala
# Song: Miss The Rage (feat. Playboi Carti), By: Trippie Redd
# Song: Starchild, By: Burn Pilot
# Song: Young Blood, By: The Naked And Famous
# Song: Saturday, By: Twenty One Pilots
# Song: LMLY, By: Jackson Wang
# Song: My Hero, By: Foo Fighters
# Song: Everlong, By: Foo Fighters
# Song: Times Like These, By: Foo Fighters
# Song: the angel of 8th ave., By: Gang of Youths
# Song: love race (feat. Kellin Quinn), By: Machine Gun Kelly
# Song: Enghave, By: Marco Egeberg
# Song: Under Pressure, By: Queen
# Song: Relax, By: Frankie Goes To Hollywood
# Song: Mr. Roboto, By: Styx
# Song: Rockstar, By: Mallrat
# Song: Galaxies, By: Laura Veirs
# Song: A Man And A Woman, By: Charlie Byrd
# Song: Over Now (with The Weeknd), By: Calvin Harris
# Song: If I Got It (Your Love Brought It), By: Aaron Frazer
# Song: Cane Shuga, By: Glass Animals
# Song: Moon Rider (feat. Wrabel), By: Jai Wolf
# Song: When Am I Gonna Lose You, By: Local Natives
# Song: Electric Feel, By: Lucy Daydream
# Song: Shout, By: Tears For Fears
# Song: Fully Alive, By: Flyleaf
# Song: Broken, By: Tears For Fears
# Song: Head Over Heels / Broken, By: Tears For Fears
# Song: Don't You (Forget About Me), By: Simple Minds
# Song: Animal, By: Def Leppard
# Song: Mad World (Feat. Michael Andrews), By: Gary Jules
# Song: Thing For You, By: Randall Bramblett
# Song: Don't You (Forget About Me), By: David Cook
# Song: More Than This, By: Roxy Music
# Song: cherry blossom, By: slenderbodies
# Song: out 4 a breather, By: dad sports
# Song: Horizon, By: Nujabes
# Song: Two Hearts, By: Zola Blood
# Song: Nightfall, By: Mimi Page
# Song: Secunda, By: Jeremy Soule
# Song: The World Retreats, By: David O'Dowda
# Song: Atlas - From “The Hunger Games: Catching Fire” Soundtrack, By: Coldplay
# Song: Weird Fishes/ Arpeggi, By: Radiohead
# Song: Tur, By: Marco Egeberg
# Song: With you, By: Cécile Corbel
# Song: Exploration, By: Bruno Coulais
# Song: Broken Sleep, By: Agnes Obel
# Song: Midnight, By: Coldplay
# Song: Blood Pressurize, By: RemoteTreeChildren
# Song: Under The Pressure, By: The War On Drugs
# Song: Round and Round, By: Ratt
# Song: Everybody Wants To Rule The World, By: Tears For Fears
# Song: Eminence Front, By: The Who
# Song: Grab as Much (as you can), By: The Black Angels
# Song: Take on Me, By: a-ha
# Song: Metal Gods, By: Judas Priest
# Song: Wake Me Up Before You Go-Go, By: Wham!
# Song: Mad World, By: Tears For Fears
# Song: Hysteria, By: Def Leppard
# Song: Who Are You, By: The Who
# Song: Diamonds and Rust, By: Judas Priest
# Song: Helter Skelter - Live, By: U2
# Song: Secrets, By: The Weeknd
# Song: Pale Shelter - 2nd Single Version, By: Tears For Fears
# Song: Armageddon It, By: Def Leppard
# Song: Careless Whisper, By: George Michael
# Song: Strangers, By: Roosevelt
# Song: Photograph, By: Def Leppard
# Song: Walk This Way, By: Aerosmith
# Song: Where The Streets Have No Name - Remastered, By: U2
# Song: Helter Skelter - Outtake - 1975, By: Aerosmith
# Song: Dancing Queen, By: ABBA
# Song: BoJack's Theme, By: Patrick Carney
# Song: Cold Cold Man, By: Saint Motel
# Song: A Horse with No Name, By: Patrick Carney
# Song: Back in the 90's, By: Grouplove
# Song: Stars (Live at Montreux), By: Nina Simone
# Song: A Horse with No Name, By: America
# Song: Hallway, By: Jesse Novak
# Song: I Will Always Think of You, By: Jane Krakowski
# Song: BoJack's Theme (Full Length), By: Patrick Carney
# Song: Mr. Peanutbutter's House Theme, By: Jesse Novak
# Song: Fragments of Time (feat. Todd Edwards), By: Daft Punk
# Song: For the Damaged Coda, By: Blonde Redhead
